# %% [markdown]
# # Data Visualization commands in Python

# %% [markdown]
# Visualizations play a key role in data analysis. In this reading, you'll be introduced to various forms of graphs and plots that you can create with your data in Python that help you in visualising your data for better analysis.
#
# The two major libraries used to create plots are matplotlib and seaborn. We will learn the prominent plotting functions of both these libraries as applicable to Data Analysis.

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
# Generating example data
np.random.seed(42)
num_points = 100

# Example variables
x = np.random.rand(num_points)
y1 = x + np.random.randn(num_points)
y2 = 2 * x + np.random.randn(num_points)
y3 = 0.5 * x + np.random.randn(num_points)

# Creating a DataFrame
data = pd.DataFrame({'X': x, 'Y1': y1, 'Y2': y2, 'Y3': y3})
data
# Out:
#            X        Y1        Y2        Y3
# 0   0.374540  0.461587  0.762082  0.386330
# 1   0.950714  0.651707  3.354963 -0.124860
# 2   0.731994  0.823755  1.199331  0.435799
# 3   0.598658 -1.388910  3.917486 -0.085984
# 4   0.156019 -0.063653  0.937705  0.191527
# ..       ...       ...       ...       ...
# 95  0.493796 -0.322015 -0.448271  0.744896
# 96  0.522733  0.445631  2.208629  1.712510
# 97  0.427541  0.768693  0.865315  1.173041
# 98  0.025419  0.302110 -0.930670  2.165892
# 99  0.107891  0.935075  0.677886 -0.713402
#
# [100 rows x 4 columns]

# %%
plt.plot(x,y2)

# %%
plt.scatter(x,y2)

# %%
plt.hist(x,bins=15)
# Out:
# (array([ 9.,  8., 11.,  2., 11.,  5.,  4.,  7.,  4.,  7.,  5.,  9.,  5.,
#          5.,  8.]),
#  array([0.00552212, 0.07094644, 0.13637076, 0.20179508, 0.2672194 ,
#         0.33264372, 0.39806804, 0.46349237, 0.52891669, 0.59434101,
#         0.65976533, 0.72518965, 0.79061397, 0.85603829, 0.92146262,
#         0.98688694]),
#  <BarContainer object of 15 artists>)
